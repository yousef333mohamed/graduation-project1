# %% [markdown]
# <a href="https://colab.research.google.com/github/yousef333mohamed/graduation-project1/blob/main/model_machine_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import xgboost as xgb
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/All_13100_Entries_with_Nutrient_Ranges.csv')
TARGET_COLUMN = 'label'

# %%
df.head(10)
# Out:
#      N   P    K  temperature  humidity      pH  rainfall  \
# 0   58  34   42      18.1006   60.5567  7.5063   33.1599
# 1   56  40   57      23.7085   71.4758  7.6218   27.2026
# 2  136  37   81      18.2818   68.8113  7.3104   19.4648
# 3   90  28   48      27.7032   66.6544  7.3479   48.6461
# 4   39  40   53      18.7403   53.3352  7.5331   36.7384
# 5   90  23   30      20.3537   63.8867  8.1077   34.0370
# 6  108  63  134      19.5361   66.1988  8.0388   48.3583
# 7   50  45   79      13.9142   58.4377  8.1010   47.0348
# 8   80  62  119      20.5922   66.2886  7.4375   17.3738
# 9   25   3    0      24.2475   39.2928  8.2690   20.0744
#
#                      label Plant_Category EC (mS/cm) Range Ca (ppm) Range  \
# 0       Origanum majorana      Herb_Spice    1.5-2.5 mS/cm    100-150 ppm
# 1      Coriandrum sativum    Unclassified    1.5-2.5 mS/cm    100-180 ppm
# 2          Cucurbita pepo    Fruiting_Veg    2.0-4.5 mS/cm    180-250 ppm
# 3         Mentha piperita      Herb_Spice    1.5-2.5 mS/cm    100-150 ppm
# 4        Raphanus sativus      Root_Tuber    1.8-2.8 mS/cm    100-180 ppm
# 5         Hordeum vulgare    Cereal_Grass    1.0-2.0 mS/cm     60-120 ppm
# 6           Beta vulgaris      Root_Tuber    1.8-2.8 mS/cm    100-180 ppm
# 7        Raphanus sativus      Root_Tuber    1.8-2.8 mS/cm    100-180 ppm
# 8           Daucus carota      Root_Tuber    1.8-2.8 mS/cm    100-180 ppm
# 9  Ziziphus spina-christi    Unclassified    1.5-2.5 mS/cm    100-180 ppm
#
#   Mg (ppm) Range  Na (ppm) Range (Max)
# 0      30-50 ppm              < 50 ppm
# 1      30-50 ppm              < 60 ppm
# 2      40-70 ppm  < 50 ppm (Sensitive)
# 3      30-50 ppm              < 50 ppm
# 4      30-60 ppm              < 70 ppm
# 5      15-35 ppm   Tolerant (Variable)
# 6      30-60 ppm              < 70 ppm
# 7      30-60 ppm              < 70 ppm
# 8      30-60 ppm              < 70 ppm
# 9      30-50 ppm              < 60 ppm

# %%
# إعدادات الخطوط العربية للرسومات
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']

# %% [markdown]
#  Data load and clean

# %%
# Load the data, assuming no header initially to inspect the first row
df = pd.read_csv("/content/All_13100_Entries_with_Nutrient_Ranges.csv", header=None)

# The first row contains the actual column names
df.columns = [
    'N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall',
    'label', 'Plant_Category',
    'EC_Range', 'Ca_Range', 'Mg_Range', 'Na_Range'
]

# %%
# Drop the first row which is the header row that was incorrectly read as data
df = df.iloc[1:].copy()

# Drop any residual header row if it exists
df = df[df['Plant_Category'] != 'Plant_Category']

# %%
# Convert numerical columns to float
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall']
for col in numerical_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# Drop any rows with missing values
df.dropna(inplace=True)

# %%
print(f"Data loaded and cleaned. Total samples: {len(df)}")
df.head()
# Out:
# Data loaded and cleaned. Total samples: 13100
#      N   P   K  temperature  humidity      pH  rainfall                label  \
# 1   58  34  42      18.1006   60.5567  7.5063   33.1599   Origanum majorana
# 2   56  40  57      23.7085   71.4758  7.6218   27.2026  Coriandrum sativum
# 3  136  37  81      18.2818   68.8113  7.3104   19.4648      Cucurbita pepo
# 4   90  28  48      27.7032   66.6544  7.3479   48.6461     Mentha piperita
# 5   39  40  53      18.7403   53.3352  7.5331   36.7384    Raphanus sativus
#
#   Plant_Category       EC_Range     Ca_Range   Mg_Range              Na_Range
# 1     Herb_Spice  1.5-2.5 mS/cm  100-150 ppm  30-50 ppm              < 50 ppm
# 2   Unclassified  1.5-2.5 mS/cm  100-180 ppm  30-50 ppm              < 60 ppm
# 3   Fruiting_Veg  2.0-4.5 mS/cm  180-250 ppm  40-70 ppm  < 50 ppm (Sensitive)
# 4     Herb_Spice  1.5-2.5 mS/cm  100-150 ppm  30-50 ppm              < 50 ppm
# 5     Root_Tuber  1.8-2.8 mS/cm  100-180 ppm  30-60 ppm              < 70 ppm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13100 entries, 1 to 13100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   N               13100 non-null  int64
#  1   P               13100 non-null  int64
#  2   K               13100 non-null  int64
#  3   temperature     13100 non-null  float64
#  4   humidity        13100 non-null  float64
#  5   pH              13100 non-null  float64
#  6   rainfall        13100 non-null  float64
#  7   label           13100 non-null  object
#  8   Plant_Category  13100 non-null  object
#  9   EC_Range        13100 non-null  object
#  10  Ca_Range        13100 non-null  object
#  11  Mg_Range        13100 non-null  object
#  12  Na_Range        13100 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                   N             P             K   temperature      humidity  \
# count  13100.000000  13100.000000  13100.000000  13100.000000  13100.000000
# mean      72.115802     39.446489     61.686031     21.921862     64.019293
# std       43.418087     19.023604     36.204850      5.933828     10.740221
# min        0.000000      0.000000      0.000000     -1.948600      3.928400
# 25%       36.000000     26.000000     36.000000     17.493525     57.983775
# 50%       68.000000     41.000000     57.000000     21.615050     64.346450
# 75%      104.000000     53.000000     84.000000     26.167850     70.854100
# max      213.000000    110.000000    185.000000     46.495900    100.000000
#
#                  pH      rainfall
# count  13100.000000  13100.000000
# mean       7.145258     60.418725
# std        0.729565     37.181436
# min        4.299400      0.000000
# 25%        6.681100     34.182700
# 50%        7.199900     53.237150
# 75%        7.657575     79.785750
# max        9.854600    300.882500

# %% [markdown]
# EDA

# %%
# --- 1.5. تحليل البيانات الاستكشافي (EDA) - توزيع فئات النباتات ---

plt.figure(figsize=(10, 6))
sns.countplot(y='Plant_Category', data=df, order=df['Plant_Category'].value_counts().index, palette='viridis')
plt.title(' (Plant Categories)', fontsize=16)
plt.xlabel('count', fontsize=12)
plt.ylabel('label', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipython-input-1817046181.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Plant_Category', data=df, order=df['Plant_Category'].value_counts().index, palette='viridis')

# %% [markdown]
# Histograms

# %%
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall']
df_num = df[numerical_cols]

# Set up the figure size and layout
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
fig.suptitle('distribution numerical columns', fontsize=18, y=1.02)
axes = axes.flatten()

# Plot histograms for each numerical column
for i, col in enumerate(numerical_cols):
    sns.histplot(df_num[col], bins=30, kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f' distribution {col}', fontsize=14)
    axes[i].set_xlabel(col, fontsize=12)
    axes[i].set_ylabel('count', fontsize=12)

# Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Box Plots

# %%
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall']

# Set up the figure size and layout
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(18, 20))
fig.suptitle('Distribution by plant category', fontsize=20, y=1.02)
axes = axes.flatten()

# Plot box plots for each numerical column against the target
for i, col in enumerate(numerical_cols):
    sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
    axes[i].set_title(f'Distribution of {col} by Plant Category', fontsize=16)
    axes[i].set_xlabel('Plant Category', fontsize=14)
    axes[i].set_ylabel(col, fontsize=14)
    axes[i].tick_params(axis='x', rotation=45)

# Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')
# /tmp/ipython-input-3769752907.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Plant_Category', y=col, data=df, ax=axes[i], palette='Set3')

# %% [markdown]
# Feature Engineering

# %%
# Define features (X) and target (y)
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall']
X_numerical = df[numerical_cols]
X_categorical = df[['label']] # Plant Name
y = df[TARGET_COLUMN]

# %%
# 1. Scale Numerical Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_numerical)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_numerical.columns, index=X_numerical.index)

# %%
# 2. One-Hot Encode Categorical Features (Plant Name)
X_encoded = pd.get_dummies(X_categorical, columns=['label'], prefix='Name', drop_first=True)

# %%
# 3. Combine Scaled Numerical and Encoded Categorical Features
X = pd.concat([X_scaled_df, X_encoded], axis=1)

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# %%
print(f"Features prepared. X shape: {X.shape}, y shape: {y_encoded.shape}")
# Out:
# Features prepared. X shape: (13100, 118), y shape: (13100,)

# %% [markdown]
# Train model (XGBoost)

# %%
# Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# Assuming 'y' (the target Series) is defined from previous steps in the notebook.
# This ensures 'encoder' is available for the 'num_class' parameter.
encoder = LabelEncoder()
encoder.fit(y)

model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(encoder.classes_),
    n_estimators=500,
    learning_rate=0.05,
    max_depth=7,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='merror',
    random_state=42,
    n_jobs=-1
)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1, num_class=112, ...)

# %% [markdown]
# Evaluation

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
train_acc = accuracy_score(y_train, y_pred_train)
test_acc = accuracy_score(y_test, y_pred_test)

# %%
print(f"Train Accuracy: {train_acc * 100:.2f}%")
print(f"Test Accuracy: {test_acc * 100:.2f}%")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_test, target_names=encoder.classes_))
# Out:
# Train Accuracy: 100.00%
# Test Accuracy: 99.96%
#
# Classification Report:
#
#                                   precision    recall  f1-score   support
#
#          Abelmoschus esculentus        1.00      0.95      0.97        20
#             Allium ampeloprasum        1.00      1.00      1.00        20
#                     Allium cepa        1.00      1.00      1.00        20
#                  Allium sativum        1.00      1.00      1.00        20
#                      Ammi majus        1.00      1.00      1.00        20
#                    Ammi visnaga        1.00      1.00      1.00        20
#              Anethum graveolens        1.00      1.00      1.00        20
#                Apium graveolens        1.00      1.00      1.00        20
#                Arachis hypogaea        1.00      1.00      1.00        40
#            Artemisia herba-alba        1.00      1.00      1.00        20
#                   Beta vulgaris        1.00      1.00      1.00        20
#      Beta vulgaris subsp. cicla        1.00      1.00      1.00        20
#    Beta vulgaris var. conditiva        1.00      1.00      1.00        20
#                  Brassica nigra        1.00      1.00      1.00        20
# Brassica oleracea var. botrytis        1.00      1.00      1.00        20
# Brassica oleracea var. capitata        1.00      1.00      1.00        20
#  Brassica oleracea var. italica        1.00      1.00      1.00        20
#                   Brassica rapa        1.00      1.00      1.00        20
#                 Capsicum annuum        1.00      1.00      1.00        20
#    Capsicum annuum var. grossum        1.00      1.00      1.00        20
#             Capsicum frutescens        1.00      1.00      1.00        20
#                   Carica papaya        1.00      1.00      1.00        20
#                     Carum carvi        1.00      1.00      1.00        40
#                 Cicer arietinum        1.00      1.00      1.00        20
#               Citrullus lanatus        1.00      1.00      1.00        20
#                Citrus aurantium        1.00      1.00      1.00        20
#                    Citrus limon        1.00      1.00      1.00        20
#                   Citrus medica        1.00      1.00      1.00        20
#                 Citrus paradisi        1.00      1.00      1.00        20
#               Citrus reticulata        1.00      1.00      1.00        20
#                 Citrus sinensis        1.00      1.00      1.00        20
#             Colocasia esculenta        1.00      1.00      1.00        20
#             Corchorus olitorius        1.00      1.00      1.00        20
#              Coriandrum sativum        1.00      1.00      1.00        20
#                    Cucumis melo        1.00      1.00      1.00        20
# Cucumis melo var. cantalupensis        1.00      1.00      1.00        20
#                 Cucumis sativus        1.00      1.00      1.00        20
#              Cucurbita moschata        1.00      1.00      1.00        40
#                  Cucurbita pepo        1.00      1.00      1.00        20
#                 Cuminum cyminum        1.00      1.00      1.00        40
#                   Curcuma longa        1.00      1.00      1.00        20
#                   Daucus carota        1.00      1.00      1.00        20
#                  Diospyros kaki        1.00      1.00      1.00        20
#                    Ficus carica        1.00      1.00      1.00        20
#                 Ficus sycomorus        1.00      1.00      1.00        20
#              Foeniculum vulgare        1.00      1.00      1.00        40
#             Fragaria × ananassa        1.00      1.00      1.00        20
#                     Glycine max        1.00      1.00      1.00        40
#            Gossypium barbadense        1.00      1.00      1.00        20
#               Helianthus annuus        1.00      1.00      1.00        40
#             Hibiscus sabdariffa        1.00      1.00      1.00        40
#                 Hordeum vulgare        1.00      1.00      1.00        40
#                 Ipomoea batatas        1.00      1.00      1.00        20
#           Jasminum grandiflorum        1.00      1.00      1.00        20
#                  Lactuca sativa        1.00      1.00      1.00        20
#                  Lens culinaris        1.00      1.00      1.00        40
#             Linum usitatissimum        1.00      1.00      1.00        40
#                   Lupinus albus        1.00      1.00      1.00        40
#                 Malus domestica        1.00      1.00      1.00        20
#                Mangifera indica        1.00      1.00      1.00        20
#               Manihot esculenta        1.00      1.00      1.00        20
#           Matricaria chamomilla        1.00      1.00      1.00        20
#             Melissa officinalis        1.00      1.00      1.00        20
#                 Mentha piperita        1.00      1.00      1.00        20
#                  Mentha spicata        1.00      1.00      1.00        20
#                  Musa acuminata        1.00      1.00      1.00        20
#                  Nigella sativa        1.00      1.00      1.00        20
#                Ocimum basilicum        1.00      1.00      1.00        40
#              Ocimum tenuiflorum        1.00      1.00      1.00        20
#                   Olea europaea        1.00      1.00      1.00        20
#            Opuntia ficus-indica        1.00      1.00      1.00        20
#               Origanum majorana        1.00      1.00      1.00        40
#                    Oryza sativa        1.00      1.00      1.00        20
#          Pelargonium graveolens        1.00      1.00      1.00        20
#              Pennisetum glaucum        1.00      1.00      1.00        20
#            Petroselinum crispum        1.00      1.00      1.00        20
#              Phaseolus vulgaris        1.00      1.00      1.00        20
#             Phoenix dactylifera        1.00      1.00      1.00        20
#               Pimpinella anisum        1.00      1.00      1.00        40
#                   Pisum sativum        1.00      1.00      1.00        40
#              Portulaca oleracea        1.00      1.00      1.00        20
#                Prunus armeniaca        1.00      1.00      1.00        20
#                    Prunus avium        1.00      1.00      1.00        20
#                Prunus domestica        1.00      1.00      1.00        20
#                  Prunus persica        1.00      1.00      1.00        20
#                 Psidium guajava        1.00      1.00      1.00        20
#                 Punica granatum        1.00      1.00      1.00        20
#                  Pyrus communis        1.00      1.00      1.00        20
#                Raphanus sativus        1.00      1.00      1.00        20
#                  Rosa damascena        1.00      1.00      1.00        20
#                    Rosa gallica        1.00      1.00      1.00        20
#          Rosmarinus officinalis        1.00      1.00      1.00        20
#           Saccharum officinarum        1.00      1.00      1.00        20
#              Salvia officinalis        1.00      1.00      1.00        20
#                 Sesamum indicum        1.00      1.00      1.00        60
#            Simmondsia chinensis        1.00      1.00      1.00        20
#            Solanum lycopersicum        0.95      1.00      0.98        20
#               Solanum melongena        1.00      1.00      1.00        20
#               Solanum tuberosum        1.00      1.00      1.00        20
#                 Sorghum bicolor        1.00      1.00      1.00        20
#               Spinacia oleracea        1.00      1.00      1.00        20
#                 Thymus vulgaris        1.00      1.00      1.00        20
#       Trigonella foenum-graecum        1.00      1.00      1.00        20
#               Triticum aestivum        1.00      1.00      1.00        20
#                      Vicia faba        1.00      1.00      1.00        20
#               Vigna unguiculata        1.00      1.00      1.00        40
#                  Vitis vinifera        1.00      1.00      1.00        20
#                        Zea mays        1.00      1.00      1.00        20
#            Zea mays var. everta        1.00      1.00      1.00        20
#         Zea mays var. indentata        1.00      1.00      1.00        20
#             Zingiber officinale        1.00      1.00      1.00        20
#          Ziziphus spina-christi        1.00      1.00      1.00        20
#
#                         accuracy                           1.00      2620
#                        macro avg       1.00      1.00      1.00      2620
#                     weighted avg       1.00      1.00      1.00      2620

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, encoder.transform(y), cv=5, scoring='accuracy')
print("Cross-validation accuracy:", scores)
print("Mean accuracy:", scores.mean() * 100)
# Out:
# Cross-validation accuracy: [0.99923664 1.         0.99961832 0.99961832 0.99961832]
# Mean accuracy: 99.9618320610687

# %%
# استرجاع الأسماء الأصلية
y_pred_labels = encoder.inverse_transform(y_pred_test)
y_true_labels = encoder.inverse_transform(y_test)

# %%
# عرض أول 10 نتائج للمقارنة
results_df = pd.DataFrame({
    'Actual': y_true_labels[:10],
    'Predicted': y_pred_labels[:10]
})

print("\n🔍 مقارنة بين القيم الحقيقية والمتوقعة:")
print(results_df)
# Out:
# 🔍 مقارنة بين القيم الحقيقية والمتوقعة:
#                      Actual                 Predicted
# 0       Coriandrum sativum        Coriandrum sativum
# 1           Lactuca sativa            Lactuca sativa
# 2       Salvia officinalis        Salvia officinalis
# 3           Vitis vinifera            Vitis vinifera
# 4  Zea mays var. indentata   Zea mays var. indentata
# 5        Triticum aestivum         Triticum aestivum
# 6      Linum usitatissimum       Linum usitatissimum
# 7          Thymus vulgaris           Thymus vulgaris
# 8         Raphanus sativus          Raphanus sativus
# 9         Prunus domestica          Prunus domestica

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Re-establish dependencies due to kernel state or non-sequential execution.
# These variables should ideally be defined in earlier cells.
TARGET_COLUMN = 'label'

# Load the data, assuming no header initially to inspect the first row
df = pd.read_csv('/content/All_13100_Entries_with_Nutrient_Ranges.csv', header=None)

# The first row contains the actual column names
df.columns = [
    'N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall',
    'label', 'Plant_Category',
    'EC_Range', 'Ca_Range', 'Mg_Range', 'Na_Range'
]

# Drop the first row which is the header row that was incorrectly read as data
df = df.iloc[1:].copy()

# Drop any residual header row if it exists
df = df[df['Plant_Category'] != 'Plant_Category']

# Convert numerical columns to float
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'pH', 'rainfall']
for col in numerical_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Drop any rows with missing values
df.dropna(inplace=True)

# Re-define y
y = df[TARGET_COLUMN]

# Re-create encoder and fit it
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

print("Classes in training:", encoder.classes_)

# y_test and y_pred_test are not defined if earlier model training cells were not executed.
# These lines are commented out to prevent further NameErrors.
# To properly evaluate, ensure all previous cells (data loading, preprocessing, model training) are run.
# print("Unique in y_test:", np.unique(y_test))
# print("Unique in y_pred:", np.unique(y_pred_test))
# Out:
# Classes in training: ['Abelmoschus esculentus ' 'Allium ampeloprasum ' 'Allium cepa '
#  'Allium sativum ' 'Ammi majus ' 'Ammi visnaga ' 'Anethum graveolens '
#  'Apium graveolens ' 'Arachis hypogaea ' 'Artemisia herba-alba '
#  'Beta vulgaris ' 'Beta vulgaris subsp. cicla '
#  'Beta vulgaris var. conditiva ' 'Brassica nigra '
#  'Brassica oleracea var. botrytis ' 'Brassica oleracea var. capitata '
#  'Brassica oleracea var. italica ' 'Brassica rapa ' 'Capsicum annuum '
#  'Capsicum annuum var. grossum ' 'Capsicum frutescens ' 'Carica papaya '
#  'Carum carvi ' 'Cicer arietinum ' 'Citrullus lanatus '
#  'Citrus aurantium ' 'Citrus limon ' 'Citrus medica ' 'Citrus paradisi '
#  'Citrus reticulata ' 'Citrus sinensis ' 'Colocasia esculenta '
#  'Corchorus olitorius ' 'Coriandrum sativum ' 'Cucumis melo '
#  'Cucumis melo var. cantalupensis ' 'Cucumis sativus '
#  'Cucurbita moschata ' 'Cucurbita pepo ' 'Cuminum cyminum '
#  'Curcuma longa ' 'Daucus carota ' 'Diospyros kaki ' 'Ficus carica '
#  'Ficus sycomorus ' 'Foeniculum vulgare ' 'Fragaria × ananassa '
#  'Glycine max ' 'Gossypium barbadense ' 'Helianthus annuus '
#  'Hibiscus sabdariffa ' 'Hordeum vulgare ' 'Ipomoea batatas '
#  'Jasminum grandiflorum ' 'Lactuca sativa ' 'Lens culinaris '
#  'Linum usitatissimum ' 'Lupinus albus ' 'Malus domestica '
#  'Mangifera indica ' 'Manihot esculenta ' 'Matricaria chamomilla '
#  'Melissa officinalis ' 'Mentha piperita ' 'Mentha spicata '
#  'Musa acuminata ' 'Nigella sativa ' 'Ocimum basilicum '
#  'Ocimum tenuiflorum ' 'Olea europaea ' 'Opuntia ficus-indica '
#  'Origanum majorana ' 'Oryza sativa ' 'Pelargonium graveolens '
#  'Pennisetum glaucum ' 'Petroselinum crispum ' 'Phaseolus vulgaris '
#  'Phoenix dactylifera ' 'Pimpinella anisum ' 'Pisum sativum '
#  'Portulaca oleracea ' 'Prunus armeniaca ' 'Prunus avium '
#  'Prunus domestica ' 'Prunus persica ' 'Psidium guajava '
#  'Punica granatum ' 'Pyrus communis ' 'Raphanus sativus '
#  'Rosa damascena ' 'Rosa gallica ' 'Rosmarinus officinalis '
#  'Saccharum officinarum ' 'Salvia officinalis ' 'Sesamum indicum '
#  'Simmondsia chinensis ' 'Solanum lycopersicum ' 'Solanum melongena '
#  'Solanum tuberosum ' 'Sorghum bicolor ' 'Spinacia oleracea '
#  'Thymus vulgaris ' 'Trigonella foenum-graecum ' 'Triticum aestivum '
#  'Vicia faba ' 'Vigna unguiculata ' 'Vitis vinifera ' 'Zea mays '
#  'Zea mays var. everta ' 'Zea mays var. indentata ' 'Zingiber officinale '
#  'Ziziphus spina-christi ']
